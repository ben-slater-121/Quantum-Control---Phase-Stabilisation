# %% [markdown]
# # Heater Characterisation

# %%
#run this cell if you want to be able to autoreload packages
#(meaning that you don't have to restart the kernal when you make changes to code)

# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np 
import matplotlib.pyplot as plt
import time
import ZeroLevel_Qontrol as q0
import FirstLevel_Qontrol as q1
import SecondLevel_Qontrol as q2
from powermeter import Powermeter as PM
import heater_dict as hd
import heater_characterisation_funcs as hcf
from tunicsqontrol import tunics
import LivePlotting as LP
# %matplotlib inline
import collections
import Chip_configurations as CF

pi=np.pi

# %% [markdown]
# ## Initialise

# %%
# powermeter1 = Powermeter('PM100USB', serial='P2003916', unit='dBm', wavelength=1550) 
unit='dBm'
wavelength=1550
#Alice (tele) powermeters 10/03/20:
PMa = PM('PM100USB', serial='P2007347',unit=unit)
PMb = PM('PM100USB', serial='P2010371',unit=unit) 
PMc = PM('PM100USB', serial='P2003683',unit=unit) 
PMd = PM('PM100USB', serial='P2008115',unit=unit)
#Charlie powermeters 10/03/20:
PMe = PM('PM100USB', serial='P2005653',unit=unit)
PMf = PM('PM100USB', serial='P2010372',unit=unit) 
PMg = PM('PM100USB', serial='P2008116',unit=unit) 
PMh = PM('PM100USB', serial='P2007346',unit=unit)

# %%
serial_port_name = 'COM12'
mytunics = tunics(serial_port_name = serial_port_name)
# Out:
# Connected to Tunics laser on serial port COM12

# %%
"""serial_port_name_qontrol = 'COM3'
q = q0.QXOutput(serial_port_name=serial_port_name_qontrol, response_timeout=0.1)
heaters = q1.HeaterQontrol(q, uep.heater_dict, default_max_v=7)"""
h=q2.heater_class(hd.board_list,hd.heaters)

# %%
p_wavelength = 1549.3
i_wavelength = 1558.98
s_wavelength = 1539.77

# %%
mytunics.laser_switch('off')
h.set_all_zeros_bad()

# %%
h.set_many_phases({
    #Bob
    "Atta1":pi,
    "Atta2":pi,
    "Atta3":pi,
    "Atta4":pi,
    "MZIa1":0,
    "MZIa2":0,
    "MZIa3":pi,
    "MZIa4":pi,
    })

# %%
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on') 
mytunics.laser_power(3)

# %%
heater_signal = {"PMa":PMa,"PMb":PMb, "PMc":PMc,"PMd":PMd}
heater_idler = {"PMe":PMe,"PMf":PMf, "PMg":PMg,"PMh":PMh}

# %%
LP.live_opt_pow(heaters = heater_idler)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-edc4bfac4c31> in <module>
# ----> 1 LP.live_opt_pow(heaters = heater_idler)
#
# ~\University of Bristol\grp-Multi 3 Chip Project - Documents\Multi_3_Chips\pycode_molly\Experimental code\LivePlotting.py in live_opt_pow(heaters)
#      25         for i in heaters.keys():
#      26             heater_data[i].append(heaters[i].measure())
# ---> 27         live_plot(heater_data)
#      28
#      29 def Swabian_counts(channels, sleep_time = 1):
#
# ~\University of Bristol\grp-Multi 3 Chip Project - Documents\Multi_3_Chips\pycode_molly\Experimental code\LivePlotting.py in live_plot(data_dict, figsize, title, xlabel, ylabel)
#      16     plt.ylabel(ylabel)
#      17     plt.legend(loc='center left') # the plot evolves to the right
# ---> 18     plt.show();
#      19
#      20 def live_opt_pow(heaters):
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     302             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     303         else:
# --> 304             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     305             if not format_dict:
#     306                 # nothing to display (e.g. _ipython_display_ took over)
#
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <C:\Program Files\Anaconda3\lib\site-packages\decorator.py:decorator-gen-9> in __call__(self, obj)
#
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1206
#    1207         for tick in ticks_to_draw:
# -> 1208             tick.draw(renderer)
#    1209
#    1210         # scale up the axis label box to also find the neighbors, not
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer)
#     295         for artist in [self.gridline, self.tick1line, self.tick2line,
#     296                        self.label1, self.label2]:
# --> 297             artist.draw(renderer)
#     298         renderer.close_group(self.__name__)
#     299         self.stale = False
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\lines.py in draw(self, renderer)
#     800
#     801                 gc.set_dashes(self._dashOffset, self._dashSeq)
# --> 802                 renderer.draw_path(gc, tpath, affine.frozen())
#     803                 gc.restore()
#     804
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     144         else:
#     145             try:
# --> 146                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     147             except OverflowError:
#     148                 raise OverflowError("Exceeded cell block limit (set "
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\transforms.py in __array__(self, *args, **kwargs)
#     279
#     280     def __array__(self, *args, **kwargs):
# --> 281         return self.get_points()
#     282
#     283     def is_unit(self):
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\transforms.py in get_points(self)
#    1034                  [p[1, 0], p[0, 1]],
#    1035                  [p[0, 0], p[1, 1]],
# -> 1036                  [p[1, 0], p[1, 1]]])
#    1037             points = np.ma.filled(points, 0.0)
#    1038
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\transforms.py in transform(self, values)
#    1392
#    1393         # Transform the values
# -> 1394         res = self.transform_affine(self.transform_non_affine(values))
#    1395
#    1396         # Convert the result back to the shape of the input values.
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\transforms.py in transform_affine(self, points)
#    2371     def transform_affine(self, points):
#    2372         # docstring inherited
# -> 2373         return self.get_affine().transform(points)
#    2374
#    2375     def transform_non_affine(self, points):
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\transforms.py in get_affine(self)
#    2399         else:
#    2400             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
# -> 2401                                 self._a.get_affine().get_matrix()))
#    2402
#    2403     def inverted(self):
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\transforms.py in get_affine(self)
#    2399         else:
#    2400             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
# -> 2401                                 self._a.get_affine().get_matrix()))
#    2402
#    2403     def inverted(self):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Calibration (Alice)

# %% [markdown]
# ### Prj_RY1 -> input 21 output 7 (Happy) - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,2,1e-3,1e-3]
phase_offset = pi
# phases_to_set={'Prj_RY1':pi}
phases_to_set = {'BS1':pi}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMb, "Prj_RY1",phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.18305567837945894 0.7985431469857255 -0.07061732196564803 0.07061769915792192
# fit visibility = -0.9999946586722821
# data visibility = 0.9980135698222444

# %%
print(powers_mW.max())

# %%
h.set_phase('Prj_RY1',pi)

# %%
unit='mW'
print(PMd.measure())
# Out:
# -88.72479336970557

# %%
h.set_many_phases({'BS1':0, 'BS3':0, 'WDM4':pi, 'Prj_RY4':pi, 'Ctr_2':pi})

# %%
h.set_many_phases({'Prj_RY4':pi+0.1, 'Ctr_2':pi})

# %%
mytunics.laser_switch('on')
mytunics.laser_wavelength(s_wavelength)

# %%
PMd.measure()
# Out:
# -9.271506530044103

# %% [markdown]
# ### WDM1 -> input 5 output 8 (Happy) - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(s_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,2,1e-3,1e-3]
phase_offset = 0
# phases_to_set={'Prj_RY1':pi}
phases_to_set = {'BS1':pi, 'BS2':pi, 'Pre_RY1':pi, 'Bell1':pi, 'Prj_RY2':pi}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMe, "WDM1",phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.20373314989581823 0.41899924097438745 0.014393635320559055 0.00010367961764198151
# fit visibility = 138.82801314200492
# data visibility = 0.9627185021118689

# %% [markdown]
# ### BS2 -> input 3 output 6 (Happy) - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset = pi
phases_to_set={'BS1':pi}#'WDM1':3*pi/2 for pump from top

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMa, "BS2" ,phases_to_set, v_max=2.9, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.21393702272514448 2.140386254574002 -4.014106440065598e-05 5.899473406812203e-05
# fit visibility = -0.6804177531219064
# data visibility = 0.5144081403707653

# %% [markdown]
# ### BS1 -> input 23 output 6 (Happy) - Ben 30072020

# %%
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset = pi
# phases_to_set={'Prj_RY1':pi, 'WDM1':3*pi/2, 'BS2': 0}
phases_to_set = {}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMa, "BS1",phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.17568549134976683 1.3465407335430588 0.04346850761751869 -7.108690750699738e-05
# fit visibility = -611.4840150169692
# data visibility = 0.9973847290539498

# %% [markdown]
# ### WDM2 -> input 23 output 8 (Happy) - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(s_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,2,1e-3,1e-3]
phase_offset = 0
phases_to_set={'BS1':pi, 'BS2':0, 'Pre_RY1':0, 'Bell1':pi, 'Prj_RY2':pi}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMe, "WDM2", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.19208722559314834 1.4265946361310509 0.038385733412347176 0.040577037601645424
# fit visibility = 0.9459964472810753
# data visibility = 0.3343145160662594

# %% [markdown]
# ### Prj_RY2 -> input 23 output 8 (Happy) - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset = 0
phases_to_set={'BS1':pi, 'BS2':0, 'WDM1':pi}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMe, "Prj_RY2", phases_to_set, v_max=3.3, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.17970918688616028 3.18095067204456 0.4104969008866122 0.009729372650107771
# fit visibility = 42.191507679795286
# data visibility = 0.9540578578239035

# %% [markdown]
# ### Bell1 -> input 23 output 9 (Happy) - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset = 0
phases_to_set={'BS1':pi, 'BS2':0, 'WDM1':pi/2, 'Prj_RY2':0}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMf, "Bell1", phases_to_set, v_max=3.3, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.1814250807109304 2.3351002290127916 0.07071441575045719 -4.9498415166034354e-06
# fit visibility = -14286.19795467334
# data visibility = 0.9807053009184226

# %% [markdown]
# ### Bell2 -> input 23 output 8 (Happy) - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,0.0,1e-3,1e-3]
phase_offset = 0
phases_to_set={'BS1':pi, 'BS2':0, 'WDM1':pi/2, 'Prj_RY2':pi, 'Pre_RY1':0}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMf, "Bell2", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.18559573744666494 -0.7002161440085315 0.07079922729532068 0.0008786318065882125
# fit visibility = 80.57894872966064
# data visibility = 0.9551332894689769

# %% [markdown]
# ### Pre_RY1 -> input 23 output 8 (Happy) - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,0.0,1e-3,1e-3]
phase_offset =0
phases_to_set={'BS1':pi, 'BS2':0, 'WDM1':pi/2, 'Prj_RY2':0, 'Bell1':pi}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMf, "Pre_RY1", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.1749192829719087 -1.4209584206047432 0.0736053572772111 0.0013391967547746486
# fit visibility = 54.96231753458582
# data visibility = 0.9702870672599283

# %% [markdown]
# ### Prj_RZ1 -> input 23 output 7 (Happy) - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset = pi
phases_to_set={'BS1':pi, 'BS2':pi/2, 'WDM1':3*pi/2, 'WDM2':3*pi/2, 'Prj_RY1':pi/2}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMb, "Prj_RZ1", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.1724901596599741 2.057775858596815 0.10231116377299243 0.0024666120820528766
# fit visibility = 41.47841669851968
# data visibility = 0.956508070689124

# %% [markdown]
# ### Pre_RZ1 -> input 23 output 9 Happy - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset = pi
phases_to_set={'BS1':pi, 'BS2':0, 'WDM1':pi/2, 'WDM2':pi/2, 'Pre_RY1':pi/2, 'Bell1':pi, 'Bell2':pi, 'Prj_RY2':pi/2}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMf, "Pre_RZ1", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# -0.19744751290112228 6.253001057252493 0.05892492832487951 0.013306864456805291
# fit visibility = 4.428160256396433
# data visibility = 0.687405885928637

# %% [markdown]
# ### Prj_RZ2 -> input 23 output 8 Happy - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset = 0 
phases_to_set={'BS1':pi, 'BS2':0, 'WDM1':pi, 'Pre_RY1':pi/2, 'Bell1':pi, 'Bell2':pi, 'Prj_RY2':pi/2}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMe, "Prj_RZ2", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# -0.2170587339854951 5.850261752274164 0.28168294647729225 0.46748750032199793
# fit visibility = 0.6025464772497094
# data visibility = 0.22729912698568944

# %% [markdown]
# ### WDM3 -> input 23 output 8 (Happy) - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(s_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset = 0
phases_to_set={'BS1':0, 'BS3':pi}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMe, "WDM3", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.19568166828962383 2.6643793842009718 0.09994852047074092 0.09128975099938164
# fit visibility = 1.094849305388268
# data visibility = 0.35589063442287666

# %% [markdown]
# ### WDM4 -> input 19 output 8 (Happy) - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(s_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset = 0
phases_to_set={'BS1':0, 'BS3':0}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMe, "WDM4", phases_to_set, v_max=3.3, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.20751537746661713 1.5946886721584836 0.13432647035052517 0.902372649068798
# fit visibility = 0.14885919967670025
# data visibility = 0.07564863248010746

# %% [markdown]
# ### Pre_RY2 -> input 23 output 8 Happy - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset =0
phases_to_set={'BS1':0, 'Bell1':0, 'Prj_RY2':pi}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMe, "Pre_RY2", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.18179667805771554 1.8574871572836236 1.1695385682215034 -0.0031055776824014504
# fit visibility = -376.59292016715364
# data visibility = 0.9963066380728534

# %% [markdown]
# ### Prj_RY3 -> input 23 output 10 (Happy) - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.20,3,1e-3,1e-3]
phase_offset = pi
phases_to_set={'BS1':0, 'BS3':pi, 'Pre_RY2':0, 'Bell2': pi}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMg, "Prj_RY3", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.1746327003765891 1.1936597395418216 1.7439835039440785 0.3012472698830016
# fit visibility = 5.789209325021956
# data visibility = 0.7455766005468693

# %% [markdown]
# ### BS3 -> input 23 output 17 happy - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset =0
phases_to_set={'BS1':0, 'Prj_RY4':pi, "Ctr_1":0}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMc, "BS3", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.1616827155551174 1.6477901062776728 0.876790123636507 0.0029461326274641984
# fit visibility = 297.6071462170322
# data visibility = 0.9931195743749847

# %% [markdown]
# ### Pre_RZ2 -> input 23 output 8 (Happy) - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset = pi
phases_to_set={'BS1':0, 'BS3':pi, 'Bell1':0, 'Bell2':0, 'Pre_RY2':pi/2, 'Prj_RY2':pi/2}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMe, "Pre_RZ2", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.2175691983689648 1.733091338429231 0.18400295726237922 0.9865021969528435
# fit visibility = 0.18652057525136448
# data visibility = 0.088126348845676

# %% [markdown]
# ### Prj_RZ3 -> input 23 output 10 (Happy) - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset = 0 
phases_to_set={'BS1':0, 'BS3':pi, 'Bell1': pi, 'Bell2':pi, 'Pre_RY2':pi/2, 'Prj_RY3':pi/2}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMg, "Prj_RZ3", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# voltage for Prj_RY3 was too high, so was not set
# tried to set 13.613036696474177 but max is 3.5
# 0.20153461070275772 3.752529681554691 1.6658687793167613 2.067670233762595
# fit visibility = 0.8056743053679962
# data visibility = 0.28804518659766176

# %% [markdown]
# ### Ctr_1 -> input 12 output 13 (Happy) - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)

guess = [0.30,3,1e-3,1e-3]
phase_offset = pi
phases_to_set={'BS1':0, 'BS3':0,}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMc, "Ctr_1", phases_to_set, v_max=3.3, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.18105532471581823 3.9137221987425743 0.4605992354956331 0.0016570606631970584
# fit visibility = 277.96160136163854
# data visibility = 0.997765120574136

# %% [markdown]
# ### Ctr_2 -> input 18 output 17 (It Will Do) - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.20,3,1e-3,1e-3]
phase_offset = pi
phases_to_set={'BS1':0, 'BS3':0, 'Prj_RY4':pi}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMd, "Ctr_2", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.17314791568483062 3.592714826333542 -3.157090608489397 3.147135742920086
# fit visibility = -1.0031631509990333
# data visibility = 0.9990277168920085

# %% [markdown]
# ### Prj_RY4 -> input 19 output 17 (Happy) - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.20,3,1e-3,1e-3]
phase_offset = 0 
phases_to_set={'BS1':0, 'BS3':pi}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMc, "Prj_RY4", phases_to_set, v_max=4.8, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.18379886885187535 4.1992652091281215 0.6106999603205536 0.01712772550236766
# fit visibility = 35.65563683491618
# data visibility = 0.9444894160623699

# %% [markdown]
# ### Prj_RZ4 -> input 23 output 17 (Happy) - Ben 30072020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(s_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset = pi
phases_to_set={'BS1':0, 'BS3':pi/2, 'Ctr_1':0, 'Prj_RY4':pi/2}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMc, "Prj_RZ4", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.1997534839216858 2.5719388719731606 0.13770679377369385 0.004487032617052698
# fit visibility = 30.689947126826635
# data visibility = 0.9427285322437394

# %% [markdown]
# ### MRR3 -> input 23 output 17

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset = pi
phases_to_set={ "BS1":0, "BS3":pi, "WDM3":3*pi/2, "Prj_RY4":pi, "Ctr_1":0}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMc, "MRR3", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 200)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# fitting failed
# 0 0 0 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-12-b8a4887cdeb3> in <module>
#      10 sleep=0.5
#      11 voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMc, "MRR3", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 200)
# ---> 12 print(f'fit visibility = {A/B}')
#      13 print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
#      14 mytunics.laser_switch('off')
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Calibration Charlie

# %%
mytunics.laser_switch('off')
h.set_all_zeros_bad()

# %%
h.set_many_phases({'MZIb2':pi, 'MZIb3':pi})
mytunics.laser_wavelength(s_wavelength)
mytunics.laser_switch('on')

# %%
print(PMa.measure())
print(PMb.measure())
print(PMc.measure())
print(PMd.measure())
# Out:
# -18.27364740154884
# -25.137352010197105
# -22.329473508837637
# -37.07620823607218

# %% [markdown]
# ### MZIb1 -> input 1 output 1 (Happy) - Ben 06082020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,1,1e-3,1e-3]
phase_offset =0
phases_to_set={}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMa, "MZIb1", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.15015369214323976 0.9835999004367705 0.019419598430264067 -7.387494066669285e-05
# fit visibility = -262.87125586849453
# data visibility = 0.9976353264338063

# %% [markdown]
# ### MZIb3 -> input 1 output 1 (Happy) - Ben 06082020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset = 0
phases_to_set={"MZIb2":pi/2}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMb, "MZIb3", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.14983844574161165 2.7953961662836564 0.00011124527977347946 -1.1299580762933261e-08
# fit visibility = -9845.080282837083
# data visibility = 0.9955020068620761

# %% [markdown]
# ### MZIb4 -> input 4 output 4 (Happy) 06082020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset = pi
phases_to_set={}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMc, "MZIb4", phases_to_set, phase_offset, v_max=3.5, sleep=sleep, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.1476504395038071 2.110731462094798 0.0001941867107182321 2.5725722831923606e-08
# fit visibility = 7548.348086735258
# data visibility = 0.9990099712505789

# %% [markdown]
# ### MZIb2 -> input 4 output 4 (Happy) - Ben 06082020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset = 0
phases_to_set={}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMd, "MZIb2", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.14788385665947376 1.9229606347622625 7.572149600623666e-05 -5.912489298022811e-07
# fit visibility = -128.0704153351425
# data visibility = 0.9994113268931138

# %% [markdown]
# ### Attb1 -> input 1 output 1 (Happy) - Ben 06082020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset =0
phases_to_set={}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMa, "Attb1", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.15086504496846498 1.6686352261895505 0.015455641338403363 -0.0001506874772202579
# fit visibility = -102.56752335041124
# data visibility = 0.9988651391378687

# %% [markdown]
# ### Attb4 -> input 4 output 4 (Happy) - Ben 06082020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset =0
phases_to_set={}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMd, "Attb4", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.15204566104994582 1.3881626581874114 7.878284510386129e-05 -1.0918336255626441e-06
# fit visibility = -72.15645612971745
# data visibility = 0.9994732833095767

# %% [markdown]
# ### Attb2 -> input 2 output 1 (Happy) - Ben 06082020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset = 0
phases_to_set={}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMa, "Attb2", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.15007315102526483 2.2455979388172222 -0.0005598641743983697 0.0005693774491719796
# fit visibility = -0.9832917956490118
# data visibility = 0.9964101514115308

# %% [markdown]
# ### Attb3 -> input 3 output 1 (Happy) - Ben 06082020

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset = 0
phases_to_set={}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMc, "Attb3", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.14920794408975377 1.8183477064486224 0.00015572536486263224 -1.1471463046861437e-06
# fit visibility = -135.75022142030812
# data visibility = 0.9991732443635416

# %% [markdown]
# ### Phb1 -> input A23 C1+2 output 1 (Alice output 6+7)

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(s_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,1,1e-3,1e-3]
phase_offset = 0
phases_to_set={'BS1':pi, 'BS2':0, 'WDM1':0, 'Prj_RY1':pi/2, 'Attb1':pi, 'Attb2':pi, 'MZIb1':pi/2, 'MZIb3':pi}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMe, "Phb1", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.17897457482327878 -0.6474539082132851 0.00010789756232094384 2.1281564886596943e-05
# fit visibility = 5.0700013319460995
# data visibility = 0.6476355492142175

# %% [markdown]
# ### Phb2 -> input A23 C1+2 output 1 (Alice output 6+7) NOT happy

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(s_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,0.8,1e-3,1e-3]
phase_offset = 0
phases_to_set={'BS1':pi, 'BS2':0, 'WDM1':0, 'Prj_RY1':pi/2, 'Attb1':pi, 'Attb2':pi, 'MZIb1':pi/2, 'MZIb3':pi}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMe, "Phb2", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.19934321403667105 3.7687932692392456 0.00010270197060360737 3.244598076389903e-05
# fit visibility = 3.165321811380674
# data visibility = 0.6372883857881557

# %% [markdown]
# ### Phb3 -> input A23 C3+4 output 1 (Alice output 6+7)

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(s_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset =pi
phases_to_set={'BS1':pi, 'BS2':0, 'WDM1':pi, 'Prj_RY1':pi/2, 'Attb3':pi, 'Attb4':pi, 'MZIb2':pi/2, 'MZIb3':0}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMe, "Phb3", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')

# %% [markdown]
# ### Phb4 -> input A23 C3+4 output 1 (Alice output 6+7)

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(s_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset =pi
phases_to_set={'BS1':pi, 'BS2':0, 'WDM1':pi, 'Prj_RY1':pi/2, 'Attb3':pi, 'Attb4':pi, 'MZIb2':pi/2, 'MZIb3':0}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMe, "Phb4", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')

# %% [markdown]
# ### Phb5 -> input A23 C1+3 output 1 (Alice output 6+7)

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(s_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset =pi
phases_to_set={'BS1':pi, 'BS2':0, 'WDM1':pi, 'Prj_RY1':pi/2, 'Attb1':pi, 'Attb3':pi, 'MZIb2':pi, 'MZIb3':pi/2}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMe, "Phb5", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')

# %% [markdown]
# ### Phb6 -> input A23 C2+4 output 1 (Alice output 6+7)

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(s_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset =pi
phases_to_set={'BS1':pi, 'BS2':0, 'WDM1':pi, 'Prj_RY1':pi/2, 'Attb2':pi, 'Attb4':pi, 'MZIb2':pi, 'MZIb4':pi/2}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMh, "Phb6", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')

# %% [markdown]
# ## Calibration Bob

# %%
mytunics.laser_switch('off')
h.set_all_zeros_bad()

# %%
h.set_many_phases({'MZIb2':pi, 'MZIb3':pi})
mytunics.laser_wavelength(s_wavelength)
mytunics.laser_switch('on')

# %%
print(PMa.measure())
print(PMb.measure())
print(PMc.measure())
print(PMd.measure())

# %% [markdown]
# ### Atta1 -> input 1 output 1

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset =0
phases_to_set={}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMe, "Atta1", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.1459985501429124 2.0277109083731903 0.007349343593160824 -4.1867701447707154e-05
# fit visibility = -175.53730773446375
# data visibility = 0.9989470773821321

# %% [markdown]
# ### Atta2 -> input 2 output 1

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset =0
phases_to_set={}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMf, "Atta2", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.14716976536156595 2.618067551577595 -0.0027766389842683904 0.002750920828100782
# fit visibility = -1.0093489263321926
# data visibility = 0.9931499813248424

# %% [markdown]
# ### Atta3 -> input 3 output 3

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset =0
phases_to_set={}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMg, "Atta3", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.14833171374308543 2.6987764532767478 -0.024871748424450113 0.02472927167409259
# fit visibility = -1.0057614616489812
# data visibility = 0.9997516793933399

# %% [markdown]
# ### Atta4 -> input 4 output 4

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset =0
phases_to_set={}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMh, "Atta4", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.14770111287681698 2.419054633113538 -2.5802862350225627e-06 2.393796837313334e-06
# fit visibility = -1.0779052736649672
# data visibility = 0.9856408916048881

# %% [markdown]
# ### MZIa1 -> input 1 output 1

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset = 0
phases_to_set={}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMe, "MZIa1", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# voltage for MZIa1 was too high, so was not set
# tried to set 3.4391257910836224 but max is 3.4
# voltage for MZIa1 was too high, so was not set
# tried to set 3.5 but max is 3.4
# 0.11862307327900938 2.3774762613577987 0.011518629391959778 0.00010052831108440175
# fit visibility = 114.58095005981892
# data visibility = 0.9966804237707049

# %% [markdown]
# ### MZIa2 -> input 4 output 4

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset =0
phases_to_set={"Atta4": pi}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMh, "MZIa2", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.1318108555213265 3.266758204909099 2.7447821674427763e-07 9.708848861145047e-10
# fit visibility = 282.70933111621855
# data visibility = 1.0

# %% [markdown]
# ### MZIa3 -> input 1 output 1

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.10,3,1e-3,1e-3]
phase_offset = 0
phases_to_set={}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMe, "MZIa3", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.12000298929199206 0.41836260058448727 0.021181936245258395 0.0008055546575189816
# fit visibility = 26.294846721507877
# data visibility = 0.9815067099345809

# %% [markdown]
# ### MZIa4 -> input 1 output 3

# %%
# want zero phase to correspond to signal going straight through filter, not to herald. So zero phase at min here
mytunics.laser_wavelength(p_wavelength)
mytunics.laser_switch('on')
time.sleep(2)
guess = [0.20,3,1e-3,1e-3]
phase_offset =0
phases_to_set={}

#background_voltage =0
sleep=0.5
voltages, currents, alpha, beta, gamma, powers_mW, c, phi_0, A, B = hcf.characterise_heater(h, PMg, "MZIa4", phases_to_set, v_max=3.5, sleep=sleep, phase_offset=phase_offset, fringe_fit_guess=guess,steps = 30)
print(f'fit visibility = {A/B}')
print(f'data visibility = {(powers_mW.max() - powers_mW.min())/(powers_mW.max() + powers_mW.min())}')
mytunics.laser_switch('off')
# Out:
# 0.1421595420816563 3.4488128131282934 0.0004861029132413273 4.44664558172641e-06
# fit visibility = 109.31901459360245
# data visibility = 0.9979936361291893
